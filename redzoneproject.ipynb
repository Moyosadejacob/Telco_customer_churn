# %% [markdown]
# <div style = "text-align: left"><font size = 6 color = "#00008B" face = "verdana"><b>Final project on Telco Customer Churn</b></font></div>
# <div style = "text-align: leftt"><font><i>By 'Moyosade Jacob</i></font></div>
# <div style = "text-align: leftt"><font>19th Feb 2023</font></div>

# %% [markdown]
# 1. **Data Ingestion**

# %%
# !pip install -Uq chardet

# %%
import pandas as pd
import numpy as np
import os
pd.options.display.max_columns = 200

import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.options.display.max_colwidth = None
pd.set_option("display.float_format", lambda x: '%.2f' % x)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pwd
# Out:
# 'C:\\redoneproj\\Telco_customer_churn'

# %%
FILE_NAME = "telco-customer-churn.csv"
DATA_FOLDER = "data"

# %%
main_path = os.getcwd()

# %%
main_path
# Out:
# 'C:\\redoneproj\\Telco_customer_churn'

# %%
file_path = os.path.join(os.path.join(main_path, DATA_FOLDER), FILE_NAME)
file_path
# Out:
# 'C:\\redoneproj\\Telco_customer_churn\\data\\telco-customer-churn.csv'

# %%
telco_data =pd.read_csv(file_path)

# %%
telco_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
telco_data.shape
# Out:
# (7043, 21)

# %% [markdown]
# ### Data Inspection

# %%
telco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
telco_data['TotalCharges'] = (
    pd.to_numeric
    (telco_data
     ['TotalCharges'],
     errors='coerce')
 )

# %%
telco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# ##  Exploration Data Analysis

# %% [markdown]
# 1. ## Model Building

# %%
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
telco_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X = telco_data[['customerID', 'gender', 'SeniorCitizen', 
                'Partner', 'Dependents',
                'tenure', 'PhoneService', 'MultipleLines',
                'InternetService',
                'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
                'TechSupport', 'StreamingTV', 'StreamingMovies', 
                'Contract', 'PaperlessBilling',
                 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',]]

# %%
y = telco_data["Churn"]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((4718, 20), (2325, 20))

# %% [markdown]
# ## Train Model

# %%
train_data, test_data = train_test_split( telco_data, test_size=0.33, random_state=42)

# %%
train_data.shape, test_data.shape
# Out:
# ((4718, 21), (2325, 21))

# %%
label = 'Churn'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count     4718
# unique       2
# top         No
# freq      3477
# Name: Churn, dtype: object

# %%
save_path = 'model'
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "model\"
# AutoGluon Version:  0.6.2
# Python Version:     3.9.16
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# Train Data Rows:    4718
# Train Data Columns: 20
# Label Column: Churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1034.1 MB
# 	Train Data (Original)  Memory Usage: 4.93 MB (0.5% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 6 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['customerID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['customerID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  2 | ['MonthlyCharges', 'TotalCharges']
# 		('int', [])    :  2 | ['SeniorCitizen', 'tenure']
# 		('object', []) : 15 | ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 10 | ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', ...]
# 		('float', [])     :  2 | ['MonthlyCharges', 'TotalCharges']
# 		('int', [])       :  1 | ['tenure']
# 		('int', ['bool']) :  6 | ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', ...]
# 	0.4s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.19 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.5s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.10597710894446799, Train Rows: 4218, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.736	 = Validation score   (accuracy)
# 	2.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.738	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.806	 = Validation score   (accuracy)
# 	2.07s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.802	 = Validation score   (accuracy)
# 	0.67s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.782	 = Validation score   (accuracy)
# 	1.48s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.784	 = Validation score   (accuracy)
# 	1.57s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.802	 = Validation score   (accuracy)
# 	22.87s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.784	 = Validation score   (accuracy)
# 	1.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.796	 = Validation score   (accuracy)
# 	1.58s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 8: early stopping
# 	0.8	 = Validation score   (accuracy)
# 	13.8s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.798	 = Validation score   (accuracy)
# 	1.05s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.806	 = Validation score   (accuracy)
# 	12.15s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.784	 = Validation score   (accuracy)
# 	1.78s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.812	 = Validation score   (accuracy)
# 	1.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 66.42s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("model\")

# %%
predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val   fit_time  \
# 0   WeightedEnsemble_L2      0.812       0.042978  15.248027
# 1            LightGBMXT      0.806       0.015990   2.065193
# 2        NeuralNetTorch      0.806       0.024985  12.146477
# 3              LightGBM      0.802       0.022985   0.673583
# 4              CatBoost      0.802       0.039129  22.866735
# 5       NeuralNetFastAI      0.800       0.048968  13.795384
# 6               XGBoost      0.798       0.024983   1.049664
# 7        ExtraTreesEntr      0.796       0.133916   1.575435
# 8         LightGBMLarge      0.784       0.026983   1.778897
# 9        ExtraTreesGini      0.784       0.106935   1.296028
# 10     RandomForestEntr      0.784       0.112931   1.569968
# 11     RandomForestGini      0.782       0.104934   1.482632
# 12       KNeighborsDist      0.738       0.020986   0.023986
# 13       KNeighborsUnif      0.736       0.017520   2.903847
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.002002           1.036357            2       True
# 1                 0.015990           2.065193            1       True
# 2                 0.024985          12.146477            1       True
# 3                 0.022985           0.673583            1       True
# 4                 0.039129          22.866735            1       True
# 5                 0.048968          13.795384            1       True
# 6                 0.024983           1.049664            1       True
# 7                 0.133916           1.575435            1       True
# 8                 0.026983           1.778897            1       True
# 9                 0.106935           1.296028            1       True
# 10                0.112931           1.569968            1       True
# 11                0.104934           1.482632            1       True
# 12                0.020986           0.023986            1       True
# 13                0.017520           2.903847            1       True
#
#     fit_order
# 0          14
# 1           3
# 2          12
# 3           4
# 4           7
# 5          10
# 6          11
# 7           9
# 8          13
# 9           8
# 10          6
# 11          5
# 12          2
# 13          1

# %% [markdown]
# ## Model Evaluation

# %%
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 185            No  No phone service             DSL                   No
# 2715          Yes               Yes              No  No internet service
# 3825          Yes                No              No  No internet service
# 1807          Yes                No     Fiber optic                   No
# 132           Yes                No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                   No                  Yes                   No
# 132                    No                   No                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 185                    No                   No  Month-to-month
# 2715  No internet service  No internet service  Month-to-month
# 3825  No internet service  No internet service        Two year
# 1807                   No                   No  Month-to-month
# 132                    No                   No        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges
# 185               Yes           Electronic check           24.80         24.80
# 2715              Yes  Bank transfer (automatic)           25.25        996.45
# 3825               No               Mailed check           19.35       1031.70
# 1807               No           Electronic check           76.35         76.35
# 132                No  Bank transfer (automatic)           50.55       3260.10

# %%
save_model_predictor = TabularPredictor.load(save_path)

# %%
y_pred = save_model_predictor.predict(test_data_nolab)

# %%
y_pred[0:5]
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: Churn, dtype: object

# %%
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8008602150537635
# Evaluations on test data:
# {
#     "accuracy": 0.8008602150537635,
#     "balanced_accuracy": 0.6714926866069384,
#     "mcc": 0.43917707755791546,
#     "f1": 0.5141657922350473,
#     "precision": 0.7538461538461538,
#     "recall": 0.39012738853503187
# }
# Predictions:
#  185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
#        ...
# 4147     No
# 3542     No
# 3759    Yes
# 1114     No
# 4958     No
# Name: Churn, Length: 2325, dtype: object

# %%
save_model_predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0              CatBoost    0.811613      0.802        0.036873       0.039129
# 1       NeuralNetFastAI    0.806882      0.800        0.151141       0.048968
# 2      RandomForestGini    0.804301      0.782        0.362776       0.104934
# 3               XGBoost    0.803011      0.798        0.066518       0.024983
# 4   WeightedEnsemble_L2    0.800860      0.812        0.116926       0.042978
# 5        NeuralNetTorch    0.800430      0.806        0.087946       0.024985
# 6              LightGBM    0.800000      0.802        0.043973       0.022985
# 7      RandomForestEntr    0.798710      0.784        0.283827       0.112931
# 8            LightGBMXT    0.797849      0.806        0.020986       0.015990
# 9        ExtraTreesEntr    0.795269      0.796        0.330796       0.133916
# 10       ExtraTreesGini    0.794409      0.784        0.332794       0.106935
# 11        LightGBMLarge    0.792258      0.784        0.072955       0.026983
# 12       KNeighborsUnif    0.770753      0.736        0.030041       0.017520
# 13       KNeighborsDist    0.756129      0.738        0.025983       0.020986
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   22.866735                 0.036873                0.039129
# 1   13.795384                 0.151141                0.048968
# 2    1.482632                 0.362776                0.104934
# 3    1.049664                 0.066518                0.024983
# 4   15.248027                 0.007994                0.002002
# 5   12.146477                 0.087946                0.024985
# 6    0.673583                 0.043973                0.022985
# 7    1.569968                 0.283827                0.112931
# 8    2.065193                 0.020986                0.015990
# 9    1.575435                 0.330796                0.133916
# 10   1.296028                 0.332794                0.106935
# 11   1.778897                 0.072955                0.026983
# 12   2.903847                 0.030041                0.017520
# 13   0.023986                 0.025983                0.020986
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0           22.866735            1       True          7
# 1           13.795384            1       True         10
# 2            1.482632            1       True          5
# 3            1.049664            1       True         11
# 4            1.036357            2       True         14
# 5           12.146477            1       True         12
# 6            0.673583            1       True          4
# 7            1.569968            1       True          6
# 8            2.065193            1       True          3
# 9            1.575435            1       True          9
# 10           1.296028            1       True          8
# 11           1.778897            1       True         13
# 12           2.903847            1       True          1
# 13           0.023986            1       True          2

# %%
test_data["predicted_Churn"] = y_pred

# %%
test_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 185            No  No phone service             DSL                   No
# 2715          Yes               Yes              No  No internet service
# 3825          Yes                No              No  No internet service
# 1807          Yes                No     Fiber optic                   No
# 132           Yes                No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                   No                  Yes                   No
# 132                    No                   No                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 185                    No                   No  Month-to-month
# 2715  No internet service  No internet service  Month-to-month
# 3825  No internet service  No internet service        Two year
# 1807                   No                   No  Month-to-month
# 132                    No                   No        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 185               Yes           Electronic check           24.80
# 2715              Yes  Bank transfer (automatic)           25.25
# 3825               No               Mailed check           19.35
# 1807               No           Electronic check           76.35
# 132                No  Bank transfer (automatic)           50.55
#
#       TotalCharges Churn predicted_Churn
# 185          24.80   Yes             Yes
# 2715        996.45    No              No
# 3825       1031.70    No              No
# 1807         76.35   Yes             Yes
# 132        3260.10    No              No

# %%
time_limit = 60  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
metric = 'roc_auc'  # specify your evaluation metric here
predictor = TabularPredictor(label, eval_metric=metric).fit(train_data, time_limit=time_limit, presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230215_152728\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "AutogluonModels\ag-20230215_152728\"
# AutoGluon Version:  0.6.2
# Python Version:     3.9.16
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# Train Data Rows:    4718
# Train Data Columns: 20
# Label Column: Churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    949.09 MB
# 	Train Data (Original)  Memory Usage: 4.93 MB (0.5% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 6 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['customerID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['customerID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  2 | ['MonthlyCharges', 'TotalCharges']
# 		('int', [])    :  2 | ['SeniorCitizen', 'tenure']
# 		('object', []) : 15 | ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 10 | ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', ...]
# 		('float', [])     :  2 | ['MonthlyCharges', 'TotalCharges']
# 		('int', [])       :  1 | ['tenure']
# 		('int', ['bool']) :  6 | ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', ...]
# 	0.4s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.19 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.48s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 59.52s of the 59.51s of remaining time.
# 	0.7309	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 59.41s of the 59.41s of remaining time.
# 	0.7199	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 59.29s of the 59.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-02-15 17:27:33,768	ERROR services.py:1365 -- Failed to start the dashboard: Failed to start the dashboard, return code 1
#  The last 10 lines of C:\Users\Omistaja\AppData\Local\Temp\ray\session_2023-02-15_17-27-30_714526_3664\logs\dashboard.log:
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client.py", line 59, in <module>
#     from .client_reqrep import (
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client_reqrep.py", line 72, in <module>
#     import charset_normalizer as chardet  # type: ignore[no-redef]
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\__init__.py", line 23, in <module>
#     from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\api.py", line 10, in <module>
#     from charset_normalizer.md import mess_ratio
# AttributeError: partially initialized module 'charset_normalizer' has no attribute 'md__mypyc' (most likely due to a circular import)
# 2023-02-15 17:27:33,770	ERROR services.py:1366 -- Failed to start the dashboard, return code 1
#  The last 10 lines of C:\Users\Omistaja\AppData\Local\Temp\ray\session_2023-02-15_17-27-30_714526_3664\logs\dashboard.log:
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client.py", line 59, in <module>
#     from .client_reqrep import (
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client_reqrep.py", line 72, in <module>
#     import charset_normalizer as chardet  # type: ignore[no-redef]
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\__init__.py", line 23, in <module>
#     from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\api.py", line 10, in <module>
#     from charset_normalizer.md import mess_ratio
# AttributeError: partially initialized module 'charset_normalizer' has no attribute 'md__mypyc' (most likely due to a circular import)
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\services.py", line 1352, in start_dashboard
#     raise Exception(err_msg + last_log_str)
# Exception: Failed to start the dashboard, return code 1
#  The last 10 lines of C:\Users\Omistaja\AppData\Local\Temp\ray\session_2023-02-15_17-27-30_714526_3664\logs\dashboard.log:
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client.py", line 59, in <module>
#     from .client_reqrep import (
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\aiohttp\client_reqrep.py", line 72, in <module>
#     import charset_normalizer as chardet  # type: ignore[no-redef]
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\__init__.py", line 23, in <module>
#     from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\charset_normalizer\api.py", line 10, in <module>
#     from charset_normalizer.md import mess_ratio
# AttributeError: partially initialized module 'charset_normalizer' has no attribute 'md__mypyc' (most likely due to a circular import)
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training... Skipping this model.
# 		The task's local raylet died. Check raylet.out for more information.
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 536, in after_all_folds_scheduled
#     raise processed_exception
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 504, in after_all_folds_scheduled
#     time_end_fit, predict_time, predict_1_time = self.ray.get(finished)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2282, in get
#     raise value
# ray.exceptions.LocalRayletDiedError: The task's local raylet died. Check raylet.out for more information.
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 49.93s of the 49.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 49.86s of the 49.85s of remaining time.
# 	0.8186	 = Validation score   (roc_auc)
# 	1.61s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 47.58s of the 47.58s of remaining time.
# 	0.818	 = Validation score   (roc_auc)
# 	1.65s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 45.37s of the 45.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused CatBoost_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 45.32s of the 45.31s of remaining time.
# 	0.8063	 = Validation score   (roc_auc)
# 	1.33s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 43.4s of the 43.39s of remaining time.
# 	0.8089	 = Validation score   (roc_auc)
# 	1.37s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 41.42s of the 41.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 41.35s of the 41.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 41.27s of the 41.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 41.21s of the 41.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training... Skipping this model.
# 		System error: Unknown error
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 249, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 541, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 487, in after_all_folds_scheduled
#     X, y, X_pseudo, y_pseudo = self._prepare_data()
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 656, in _prepare_data
#     X = self.ray.put(self.X)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 2345, in put
#     object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#   File "C:\Users\Omistaja\anaconda3\envs\redz_finalproj\lib\site-packages\ray\_private\worker.py", line 620, in put_object
#     self.core_worker.put_serialized_object_and_increment_local_ref(
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python\ray\_raylet.pyx", line 1254, in ray._raylet.CoreWorker._create_put_buffer
#   File "python\ray\_raylet.pyx", line 179, in ray._raylet.check_status
# ray.exceptions.RaySystemError: System error: Unknown error
# Repeating k-fold bagging: 2/20
# Repeating k-fold bagging: 3/20
# Repeating k-fold bagging: 4/20
# Repeating k-fold bagging: 5/20
# Repeating k-fold bagging: 6/20
# Repeating k-fold bagging: 7/20
# Repeating k-fold bagging: 8/20
# Repeating k-fold bagging: 9/20
# Repeating k-fold bagging: 10/20
# Repeating k-fold bagging: 11/20
# Repeating k-fold bagging: 12/20
# Repeating k-fold bagging: 13/20
# Repeating k-fold bagging: 14/20
# Repeating k-fold bagging: 15/20
# Repeating k-fold bagging: 16/20
# Repeating k-fold bagging: 17/20
# Repeating k-fold bagging: 18/20
# Repeating k-fold bagging: 19/20
# Repeating k-fold bagging: 20/20
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 59.52s of the 41.03s of remaining time.
# 	0.821	 = Validation score   (roc_auc)
# 	0.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 19.87s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230215_152728\")

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                      model  score_test  score_val  pred_time_test  \
# 0      WeightedEnsemble_L2    0.843970   0.820957        0.953396
# 1  RandomForestEntr_BAG_L1    0.843088   0.818043        0.279050
# 2  RandomForestGini_BAG_L1    0.842269   0.818646        0.273680
# 3    ExtraTreesGini_BAG_L1    0.834083   0.806295        0.318804
# 4    ExtraTreesEntr_BAG_L1    0.832726   0.808933        0.328976
# 5    KNeighborsUnif_BAG_L1    0.752457   0.730950        0.029715
# 6    KNeighborsDist_BAG_L1    0.741689   0.719939        0.028982
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       1.336175  5.502579                 0.012994                0.001997
# 1       0.398753  1.645245                 0.279050                0.398753
# 2       0.465713  1.609998                 0.273680                0.465713
# 3       0.395756  1.331173                 0.318804                0.395756
# 4       0.394757  1.365153                 0.328976                0.394757
# 5       0.030982  0.024981                 0.029715                0.030982
# 6       0.043973  0.023982                 0.028982                0.043973
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.833220            2       True          7
# 1           1.645245            1       True          4
# 2           1.609998            1       True          3
# 3           1.331173            1       True          5
# 4           1.365153            1       True          6
# 5           0.024981            1       True          1
# 6           0.023982            1       True          2
